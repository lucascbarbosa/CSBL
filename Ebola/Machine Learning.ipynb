# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor,ElasticNet,RidgeCV, LinearRegression
from sklearn.feature_selection import RFE,RFECV
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV, KFold, StratifiedShuffleSplit
from sklearn.decomposition import PCA\

import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Dropout, BatchNormalization, Input, GlobalMaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter
import os
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
sns.set()
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17165284904607196673
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4687451711350978828
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3127299276
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15240611386881885801
# physical_device_desc: "device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11426148042223561868
# physical_device_desc: "device: XLA_GPU device"
# ]

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Feature selection

# %%
def get_genes(X,y,estimators,num_genes_fold,num_genes_final,folds):
    genes_related = []
    
    for estimator in estimators:
        selector = RFECV(estimator, min_features_to_select=num_genes_fold, cv=folds, step=1)
        selector = selector.fit(X, y)
        ranking = selector.ranking_
        ranking_idx = ranking.argsort()[-num_genes_fold:][::-1]
        genes_related+=list(X.columns[ranking_idx])

    dic_count = Counter(genes_related)
    dic_count = {k: v for k, v in sorted(dic_count.items(), key=lambda item: item[1])}
    top_genes = list(dic_count.keys())[-num_genes_final:]
    return top_genes

# %% [markdown]
# ## Classification

# %% [markdown]
# ## Ajuste de hiperparâmetros

# %%
def get_hiperparams(X_train,X_test,y_train,y_test,kfold,param_grid, model,w,h,df,plot,annot):
    
    gs = GridSearchCV(estimator=model,
                      param_grid=param_grid,
                      cv=kfold)
    best_gs = gs.fit(X_train,y_train)
    n = len(param_grid)
    scores = best_gs.cv_results_['mean_test_score']
    scores = scores.reshape(len(scores),)
    
    if n == 1:
        label = list(param_grid.keys())[0]
        par = list(param_grid.values())[0]
        plt.plot(par,scores)
        plt.ylabel('F1-score')
        plt.xlabel(label)
        plt.show()
        
    if n == 2:
        
        label1,label2 = param_grid.keys()
        par1,par2 = param_grid.values()
        scores_df = pd.DataFrame(columns=par1,index=par2)
        for i in range(len(par1)*len(par2)):
            col = i % len(par1)
            row = i // len(par1)
            scores_df.iloc[row,col] = scores[i]

        scores_df = scores_df.astype(float)
        if df:
            print(scores_df)
        if plot:
            fig= plt.figure(figsize=(w,h))
            heatmap = sns.heatmap(scores_df,annot=annot)        
            plt.xlabel(label1)
            plt.ylabel(label2)
            plt.show()

    return best_gs.best_params_

# %% [markdown]
# ## Classification

# %%
n_splits = 4
test_size = 0.3 #Hp
num_genes_fold = 15
num_genes_final = 5
folds = 10
events = os.listdir('Dados/Eventos adversos')
metrics = pd.DataFrame()
metrics_ = []

n_folds = 4
test_size = 0.35

kfold = KFold(n_folds,shuffle=True,random_state=42)

max_depth = 20
depths = [i for i in range(1,max_depth+1)]
param_grid = {'max_depth':depths,
              'splitter':['best', 'random'],
              'criterion':['gini','entropy']
             }
pca = PCA(n_components=num_genes_final)

for event in events:
    dados = pd.read_csv(f'Dados/Eventos adversos/{event}')
    
    X = dados.iloc[:,:-1]
    y = dados.iloc[:,-1]
    
#     genes = get_genes(X,y,estimators,num_genes_fold,num_genes_final,folds)
#     X = X[genes]
    print(X.shape)
    X = pd.DataFrame(pca.fit_transform(X))
    print(X.shape)
    sss = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=42)

    tree_score = 0.0

    for train_index, test_index in sss.split(X, y):    
        X_train,X_test,y_train,y_test = X.iloc[train_index],X.iloc[test_index],y.iloc[train_index],y.iloc[test_index]
        hp = get_hiperparams(X_train,X_test,y_train,y_test,kfold,param_grid,DecisionTreeClassifier(random_state=42,),10,6,False,False,False)
        criterion_opt,max_depth_opt,splitter_opt = hp.values()
        #Decision Trees
        tree = make_pipeline(StandardScaler(),
                            DecisionTreeClassifier(random_state=42,
                                                   criterion=criterion_opt,
                                                   max_depth=max_depth_opt,
                                                   splitter=splitter_opt))

        tree.fit(X_train,y_train)
        pred_tree = tree.predict(X_test)
        tree_score += f1_score(y_test,pred_tree,average='weighted',pos_label="Plano ID")

    tree_score /= float(n_splits)
    
    tree_score = round(tree_score,2)
    
    metrics_.append(tree_score)

#     print(f"F1-score for {event[:-4]}: Decision Trees: {tree_score}")

metrics['Decision_trees'] = metrics_
metrics
# Out:
# (426, 38)
# (426, 5)
# (476, 38)
# (476, 5)
# (392, 38)
# (392, 5)
# (282, 38)
# (282, 5)
# (338, 38)
# (338, 5)
# (282, 38)
# (282, 5)
# (326, 38)
# (326, 5)
# (488, 38)
# (488, 5)
#    Decision_trees
# 0            0.70
# 1            0.83
# 2            0.72
# 3            0.56
# 4            0.59
# 5            0.50
# 6            0.56
# 7            0.76

# %% [markdown]
# # Classification for # of events

# %%
dados = pd.read_csv('Dados/dados soma.csv')

X_soma = dados.iloc[:,:-1]
y_soma = dados.iloc[:,-1]

estimators = [SVR(kernel='linear'),
              SGDRegressor(),
              ElasticNet(),
              RidgeCV(),
              LinearRegression()]

genes = get_genes(X_soma,y_soma,estimators,num_genes_fold,num_genes_final,folds)
X_soma = X_soma[genes]

n_splits = 4
test_size = 0.3 
num_genes_fold = 15
num_genes_final = 8
folds = 10

n_folds = 4
test_size = 0.35

kfold = KFold(n_folds,shuffle=True,random_state=42)

max_depth = 20
depths = [i for i in range(1,max_depth+1)]
param_grid = {'max_depth':depths,
              'splitter':['best', 'random'],
              'criterion':['gini','entropy']
             }

sss = StratifiedShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=42)

tree_score = 0.0

for train_index, test_index in sss.split(X_soma, y_soma):    
    X_train,X_test,y_train,y_test = X_soma.iloc[train_index],X_soma.iloc[test_index],y_soma.iloc[train_index],y_soma.iloc[test_index]
    hp = get_hiperparams(X_train,X_test,y_train,y_test,kfold,param_grid,DecisionTreeClassifier(random_state=42,),10,6,False,False,False)
    criterion_opt,max_depth_opt,splitter_opt = hp.values()

    #Decision Trees
    tree = make_pipeline(StandardScaler(),
                        DecisionTreeClassifier(random_state=42,
                                               criterion=criterion_opt,
                                               max_depth=max_depth_opt,
                                               splitter=splitter_opt))

    tree.fit(X_train,y_train)
    pred_tree = tree.predict(X_test)
    tree_score += f1_score(y_test,pred_tree,average='weighted',pos_label="Plano ID")

tree_score /= float(n_splits)

tree_score = round(tree_score,2)


print(f"F1-score: Decision Trees: {tree_score*100}%")
# Out:
# F1-score: Decision Trees: 65.0%

# %% [markdown]
# # Deep Learning

# %% [markdown]
# ## Fully Connected

# %%
epochs = 30
test_size = 0.3 
num_genes_fold = 15
num_genes_final = 8
folds = 10

estimators = [SVR(kernel='linear'),
              SGDRegressor(),
              ElasticNet(),
              RidgeCV(),
              LinearRegression()]


events = os.listdir('Dados/Eventos adversos')
for event in events:
    dados = pd.read_csv(f'Dados/Eventos adversos/{event}')    
    X = dados.iloc[:,:-1]
    y = dados.iloc[:,-1]
    genes = get_genes(X,y,estimators,num_genes_fold,num_genes_final,folds)
    X = np.array(X[genes])
    y = np.array(y)
    y = y.reshape((y.shape[0],1))

    input_size = X.shape[1]
    
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = test_size)
    
    model = Sequential()
    activation_dense = 'relu'
    model.add(Dense(32,input_dim=X.shape[1], activation=activation_dense)) 
#     model.add(Dropout(0.5))
    model.add(Dense(256, activation=activation_dense)) 
#     model.add(Dropout(0.5))
    model.add(Dense(128, activation=activation_dense))
#     model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    hist= model.fit( X_train, 
                     y_train, 
                     batch_size=32, 
                     epochs=epochs, 
                     shuffle='True', 
                     validation_data=(X_test, y_test))
    print('\n\n\n\n')
#     fig,axs=plt.subplots(2)

#     fig.set_size_inches(10,8)

#     axs[0].plot(hist.history['val_accuracy'],label='Validation')
#     axs[0].plot(hist.history['accuracy'],label='Training')
#     axs[0].set_ylabel('Accuracy')
#     axs[0].set_xlabel('Epoch')

#     axs[1].plot(hist.history['val_loss'],label='Validation')
#     axs[1].plot(hist.history['loss'],label='Training')
#     axs[1].set_ylabel('Loss')
#     axs[1].set_xlabel('Epoch')

#     plt.legend();
#     plt.show()
# Out:
# Epoch 1/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6892 - accuracy: 0.5336 - val_loss: 0.6942 - val_accuracy: 0.5469
# Epoch 2/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6781 - accuracy: 0.6141 - val_loss: 0.6766 - val_accuracy: 0.5859
# Epoch 3/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6681 - accuracy: 0.6275 - val_loss: 0.6853 - val_accuracy: 0.5781
# Epoch 4/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6548 - accuracy: 0.6544 - val_loss: 0.6650 - val_accuracy: 0.6016
# Epoch 5/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6427 - accuracy: 0.6577 - val_loss: 0.6642 - val_accuracy: 0.6094
# Epoch 6/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6345 - accuracy: 0.6611 - val_loss: 0.6711 - val_accuracy: 0.6094
# Epoch 7/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6285 - accuracy: 0.6611 - val_loss: 0.6692 - val_accuracy: 0.6094
# Epoch 8/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6211 - accuracy: 0.6745 - val_loss: 0.6649 - val_accuracy: 0.6016
# Epoch 9/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6148 - accuracy: 0.6846 - val_loss: 0.6583 - val_accuracy: 0.6016
# Epoch 10/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6075 - accuracy: 0.6611 - val_loss: 0.6598 - val_accuracy: 0.5859
# Epoch 11/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6138 - accuracy: 0.6477 - val_loss: 0.6599 - val_accuracy: 0.5781
# Epoch 12/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6120 - accuracy: 0.6477 - val_loss: 0.6494 - val_accuracy: 0.5859
# Epoch 13/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6038 - accuracy: 0.6678 - val_loss: 0.6825 - val_accuracy: 0.5859
# Epoch 14/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5955 - accuracy: 0.6745 - val_loss: 0.6471 - val_accuracy: 0.5859
# Epoch 15/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5918 - accuracy: 0.6544 - val_loss: 0.6599 - val_accuracy: 0.5625
# Epoch 16/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5806 - accuracy: 0.6913 - val_loss: 0.6657 - val_accuracy: 0.5859
# Epoch 17/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5752 - accuracy: 0.7013 - val_loss: 0.6559 - val_accuracy: 0.6016
# Epoch 18/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5714 - accuracy: 0.6812 - val_loss: 0.6814 - val_accuracy: 0.5547
# Epoch 19/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5588 - accuracy: 0.6980 - val_loss: 0.6677 - val_accuracy: 0.5625
# Epoch 20/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5586 - accuracy: 0.7148 - val_loss: 0.6695 - val_accuracy: 0.5703
# Epoch 21/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5475 - accuracy: 0.7148 - val_loss: 0.6787 - val_accuracy: 0.5625
# Epoch 22/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5444 - accuracy: 0.6980 - val_loss: 0.6605 - val_accuracy: 0.5938
# Epoch 23/30
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5475 - accuracy: 0.7148 - val_loss: 0.6777 - val_accuracy: 0.5781
# Epoch 24/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5333 - accuracy: 0.7248 - val_loss: 0.6537 - val_accuracy: 0.5859
# Epoch 25/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5485 - accuracy: 0.7282 - val_loss: 0.6975 - val_accuracy: 0.6016
# Epoch 26/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5260 - accuracy: 0.7450 - val_loss: 0.6502 - val_accuracy: 0.5703
# Epoch 27/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5187 - accuracy: 0.7282 - val_loss: 0.6853 - val_accuracy: 0.5938
# Epoch 28/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5124 - accuracy: 0.7416 - val_loss: 0.6583 - val_accuracy: 0.5781
# Epoch 29/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5049 - accuracy: 0.7584 - val_loss: 0.6763 - val_accuracy: 0.5938
# Epoch 30/30
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5107 - accuracy: 0.7148 - val_loss: 0.6632 - val_accuracy: 0.6016
#
#
#
#
#
# Epoch 1/30
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6424 - accuracy: 0.7207 - val_loss: 0.5766 - val_accuracy: 0.8042
# Epoch 2/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5426 - accuracy: 0.8018 - val_loss: 0.4908 - val_accuracy: 0.7972
# Epoch 3/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4844 - accuracy: 0.8048 - val_loss: 0.4709 - val_accuracy: 0.7972
# Epoch 4/30
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4728 - accuracy: 0.8048 - val_loss: 0.4649 - val_accuracy: 0.8042
# Epoch 5/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4522 - accuracy: 0.8078 - val_loss: 0.4490 - val_accuracy: 0.8112
# Epoch 6/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4418 - accuracy: 0.8168 - val_loss: 0.4411 - val_accuracy: 0.8322
# Epoch 7/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4275 - accuracy: 0.8168 - val_loss: 0.4282 - val_accuracy: 0.8322
# Epoch 8/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4117 - accuracy: 0.8198 - val_loss: 0.4164 - val_accuracy: 0.8322
# Epoch 9/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3967 - accuracy: 0.8318 - val_loss: 0.4050 - val_accuracy: 0.8322
# Epoch 10/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3919 - accuracy: 0.8348 - val_loss: 0.3959 - val_accuracy: 0.8322
# Epoch 11/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3744 - accuracy: 0.8408 - val_loss: 0.3899 - val_accuracy: 0.8462
# Epoch 12/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3619 - accuracy: 0.8468 - val_loss: 0.3834 - val_accuracy: 0.8392
# Epoch 13/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.8619 - val_loss: 0.3813 - val_accuracy: 0.8462
# Epoch 14/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3541 - accuracy: 0.8529 - val_loss: 0.3766 - val_accuracy: 0.8322
# Epoch 15/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3499 - accuracy: 0.8498 - val_loss: 0.3733 - val_accuracy: 0.8392
# Epoch 16/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3466 - accuracy: 0.8529 - val_loss: 0.3627 - val_accuracy: 0.8531
# Epoch 17/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3353 - accuracy: 0.8679 - val_loss: 0.3617 - val_accuracy: 0.8322
# Epoch 18/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3378 - accuracy: 0.8378 - val_loss: 0.3583 - val_accuracy: 0.8462
# Epoch 19/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3250 - accuracy: 0.8498 - val_loss: 0.3510 - val_accuracy: 0.8462
# Epoch 20/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3241 - accuracy: 0.8649 - val_loss: 0.3609 - val_accuracy: 0.8462
# Epoch 21/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3108 - accuracy: 0.8649 - val_loss: 0.3456 - val_accuracy: 0.8462
# Epoch 22/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3041 - accuracy: 0.8679 - val_loss: 0.3643 - val_accuracy: 0.8322
# Epoch 23/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3055 - accuracy: 0.8679 - val_loss: 0.3419 - val_accuracy: 0.8462
# Epoch 24/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3151 - accuracy: 0.8619 - val_loss: 0.3391 - val_accuracy: 0.8462
# Epoch 25/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3041 - accuracy: 0.8589 - val_loss: 0.3387 - val_accuracy: 0.8531
# Epoch 26/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2884 - accuracy: 0.8709 - val_loss: 0.3381 - val_accuracy: 0.8462
# Epoch 27/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2804 - accuracy: 0.8859 - val_loss: 0.3328 - val_accuracy: 0.8531
# Epoch 28/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.8889 - val_loss: 0.3282 - val_accuracy: 0.8601
# Epoch 29/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2768 - accuracy: 0.8859 - val_loss: 0.3240 - val_accuracy: 0.8392
# Epoch 30/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2699 - accuracy: 0.8829 - val_loss: 0.3239 - val_accuracy: 0.8531
#
#
#
#
#
# Epoch 1/30
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6969 - accuracy: 0.5255 - val_loss: 0.6874 - val_accuracy: 0.4915
# Epoch 2/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.5073 - val_loss: 0.6833 - val_accuracy: 0.5085
# Epoch 3/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6726 - accuracy: 0.6131 - val_loss: 0.6789 - val_accuracy: 0.6186
# Epoch 4/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6622 - accuracy: 0.6788 - val_loss: 0.6733 - val_accuracy: 0.6102
# Epoch 5/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6505 - accuracy: 0.6606 - val_loss: 0.6627 - val_accuracy: 0.6271
# Epoch 6/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6387 - accuracy: 0.6569 - val_loss: 0.6540 - val_accuracy: 0.6186
# Epoch 7/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6209 - accuracy: 0.6606 - val_loss: 0.6419 - val_accuracy: 0.6102
# Epoch 8/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6049 - accuracy: 0.6642 - val_loss: 0.6328 - val_accuracy: 0.6186
# Epoch 9/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5896 - accuracy: 0.6825 - val_loss: 0.6249 - val_accuracy: 0.6356
# Epoch 10/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5750 - accuracy: 0.7190 - val_loss: 0.6162 - val_accuracy: 0.6271
# Epoch 11/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5609 - accuracy: 0.7080 - val_loss: 0.6129 - val_accuracy: 0.6695
# Epoch 12/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5566 - accuracy: 0.6971 - val_loss: 0.6077 - val_accuracy: 0.6356
# Epoch 13/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5403 - accuracy: 0.7336 - val_loss: 0.5957 - val_accuracy: 0.6610
# Epoch 14/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5299 - accuracy: 0.7263 - val_loss: 0.5869 - val_accuracy: 0.6525
# Epoch 15/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5220 - accuracy: 0.7372 - val_loss: 0.5896 - val_accuracy: 0.6864
# Epoch 16/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5171 - accuracy: 0.7372 - val_loss: 0.5795 - val_accuracy: 0.6610
# Epoch 17/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4983 - accuracy: 0.7628 - val_loss: 0.5683 - val_accuracy: 0.6695
# Epoch 18/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.7628 - val_loss: 0.5650 - val_accuracy: 0.6695
# Epoch 19/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4840 - accuracy: 0.7482 - val_loss: 0.5724 - val_accuracy: 0.6441
# Epoch 20/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4693 - accuracy: 0.7701 - val_loss: 0.5585 - val_accuracy: 0.6864
# Epoch 21/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4765 - accuracy: 0.7737 - val_loss: 0.5654 - val_accuracy: 0.6695
# Epoch 22/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4751 - accuracy: 0.7628 - val_loss: 0.5459 - val_accuracy: 0.7203
# Epoch 23/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4455 - accuracy: 0.7810 - val_loss: 0.5533 - val_accuracy: 0.6610
# Epoch 24/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4392 - accuracy: 0.7774 - val_loss: 0.5368 - val_accuracy: 0.7034
# Epoch 25/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4371 - accuracy: 0.7920 - val_loss: 0.5311 - val_accuracy: 0.7373
# Epoch 26/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4279 - accuracy: 0.7774 - val_loss: 0.5394 - val_accuracy: 0.7203
# Epoch 27/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4272 - accuracy: 0.7920 - val_loss: 0.5259 - val_accuracy: 0.7288
# Epoch 28/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4197 - accuracy: 0.8139 - val_loss: 0.5372 - val_accuracy: 0.7373
# Epoch 29/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.8175 - val_loss: 0.5221 - val_accuracy: 0.7542
# Epoch 30/30
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3973 - accuracy: 0.8175 - val_loss: 0.5318 - val_accuracy: 0.7288
#
#
#
#
#
# Epoch 1/30
# 7/7 [==============================] - 0s 20ms/step - loss: 0.6910 - accuracy: 0.5228 - val_loss: 0.6864 - val_accuracy: 0.6353
# Epoch 2/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6861 - accuracy: 0.5635 - val_loss: 0.6901 - val_accuracy: 0.6118
# Epoch 3/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6820 - accuracy: 0.5736 - val_loss: 0.6866 - val_accuracy: 0.6118
# Epoch 4/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6799 - accuracy: 0.6091 - val_loss: 0.6830 - val_accuracy: 0.6118
# Epoch 5/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6782 - accuracy: 0.5888 - val_loss: 0.6831 - val_accuracy: 0.6118
# Epoch 6/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6729 - accuracy: 0.6244 - val_loss: 0.6851 - val_accuracy: 0.6353
# Epoch 7/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6733 - accuracy: 0.5939 - val_loss: 0.6864 - val_accuracy: 0.6235
# Epoch 8/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6726 - accuracy: 0.6193 - val_loss: 0.6845 - val_accuracy: 0.6118
# Epoch 9/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6711 - accuracy: 0.6041 - val_loss: 0.6858 - val_accuracy: 0.6235
# Epoch 10/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6625 - accuracy: 0.6193 - val_loss: 0.6883 - val_accuracy: 0.6353
# Epoch 11/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6600 - accuracy: 0.6244 - val_loss: 0.6902 - val_accuracy: 0.6235
# Epoch 12/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6578 - accuracy: 0.6142 - val_loss: 0.6935 - val_accuracy: 0.6353
# Epoch 13/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6580 - accuracy: 0.6294 - val_loss: 0.6989 - val_accuracy: 0.6353
# Epoch 14/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6554 - accuracy: 0.6091 - val_loss: 0.6962 - val_accuracy: 0.6118
# Epoch 15/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6544 - accuracy: 0.6142 - val_loss: 0.6926 - val_accuracy: 0.6588
# Epoch 16/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6535 - accuracy: 0.6345 - val_loss: 0.7092 - val_accuracy: 0.5176
# Epoch 17/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6610 - accuracy: 0.5939 - val_loss: 0.6983 - val_accuracy: 0.6353
# Epoch 18/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6464 - accuracy: 0.6193 - val_loss: 0.6980 - val_accuracy: 0.6353
# Epoch 19/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6456 - accuracy: 0.6244 - val_loss: 0.7004 - val_accuracy: 0.6353
# Epoch 20/30
# 7/7 [==============================] - ETA: 0s - loss: 0.6574 - accuracy: 0.53 - 0s 5ms/step - loss: 0.6401 - accuracy: 0.6193 - val_loss: 0.6997 - val_accuracy: 0.6118
# Epoch 21/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6371 - accuracy: 0.6294 - val_loss: 0.6955 - val_accuracy: 0.5882
# Epoch 22/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6357 - accuracy: 0.6345 - val_loss: 0.7052 - val_accuracy: 0.5529
# Epoch 23/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6364 - accuracy: 0.6193 - val_loss: 0.7097 - val_accuracy: 0.5647
# Epoch 24/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6265 - accuracy: 0.6447 - val_loss: 0.7204 - val_accuracy: 0.5529
# Epoch 25/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6470 - accuracy: 0.5838 - val_loss: 0.7126 - val_accuracy: 0.5647
# Epoch 26/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6476 - accuracy: 0.6142 - val_loss: 0.7115 - val_accuracy: 0.5765
# Epoch 27/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6340 - accuracy: 0.6345 - val_loss: 0.6991 - val_accuracy: 0.5765
# Epoch 28/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6211 - accuracy: 0.6396 - val_loss: 0.7085 - val_accuracy: 0.5647
# Epoch 29/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6319 - accuracy: 0.6041 - val_loss: 0.7115 - val_accuracy: 0.5765
# Epoch 30/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6257 - accuracy: 0.6294 - val_loss: 0.7134 - val_accuracy: 0.6118
#
#
#
#
#
# Epoch 1/30
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6919 - accuracy: 0.5212 - val_loss: 0.7125 - val_accuracy: 0.4510
# Epoch 2/30
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6867 - accuracy: 0.5678 - val_loss: 0.7038 - val_accuracy: 0.4902
# Epoch 3/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6828 - accuracy: 0.5508 - val_loss: 0.7205 - val_accuracy: 0.5000
# Epoch 4/30
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6777 - accuracy: 0.5636 - val_loss: 0.7173 - val_accuracy: 0.4902
# Epoch 5/30
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6732 - accuracy: 0.5805 - val_loss: 0.7195 - val_accuracy: 0.4706
# Epoch 6/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.6059 - val_loss: 0.7175 - val_accuracy: 0.5000
# Epoch 7/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6657 - accuracy: 0.6102 - val_loss: 0.7095 - val_accuracy: 0.4804
# Epoch 8/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6600 - accuracy: 0.5975 - val_loss: 0.7275 - val_accuracy: 0.4804
# Epoch 9/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6542 - accuracy: 0.6398 - val_loss: 0.7475 - val_accuracy: 0.4902
# Epoch 10/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6493 - accuracy: 0.6059 - val_loss: 0.7277 - val_accuracy: 0.4510
# Epoch 11/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6446 - accuracy: 0.6102 - val_loss: 0.7347 - val_accuracy: 0.4608
# Epoch 12/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6366 - accuracy: 0.6483 - val_loss: 0.7372 - val_accuracy: 0.4902
# Epoch 13/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6332 - accuracy: 0.6441 - val_loss: 0.7491 - val_accuracy: 0.5000
# Epoch 14/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6269 - accuracy: 0.6398 - val_loss: 0.7682 - val_accuracy: 0.5000
# Epoch 15/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6185 - accuracy: 0.6356 - val_loss: 0.7492 - val_accuracy: 0.5000
# Epoch 16/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6140 - accuracy: 0.6483 - val_loss: 0.7788 - val_accuracy: 0.4902
# Epoch 17/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6041 - accuracy: 0.6356 - val_loss: 0.7664 - val_accuracy: 0.5000
# Epoch 18/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6044 - accuracy: 0.6525 - val_loss: 0.7697 - val_accuracy: 0.5000
# Epoch 19/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6034 - accuracy: 0.6653 - val_loss: 0.7779 - val_accuracy: 0.4902
# Epoch 20/30
# 8/8 [==============================] - ETA: 0s - loss: 0.5889 - accuracy: 0.62 - 0s 4ms/step - loss: 0.5937 - accuracy: 0.6610 - val_loss: 0.8011 - val_accuracy: 0.5000
# Epoch 21/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6017 - accuracy: 0.6653 - val_loss: 0.7898 - val_accuracy: 0.5000
# Epoch 22/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6063 - accuracy: 0.6568 - val_loss: 0.8445 - val_accuracy: 0.4902
# Epoch 23/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5719 - accuracy: 0.6907 - val_loss: 0.7634 - val_accuracy: 0.5000
# Epoch 24/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5680 - accuracy: 0.6864 - val_loss: 0.8248 - val_accuracy: 0.4706
# Epoch 25/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5696 - accuracy: 0.6864 - val_loss: 0.8262 - val_accuracy: 0.4706
# Epoch 26/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5570 - accuracy: 0.6949 - val_loss: 0.7970 - val_accuracy: 0.4804
# Epoch 27/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5632 - accuracy: 0.7161 - val_loss: 0.8257 - val_accuracy: 0.4804
# Epoch 28/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5479 - accuracy: 0.6907 - val_loss: 0.8071 - val_accuracy: 0.4706
# Epoch 29/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5466 - accuracy: 0.7034 - val_loss: 0.8724 - val_accuracy: 0.4706
# Epoch 30/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5327 - accuracy: 0.7331 - val_loss: 0.7978 - val_accuracy: 0.4510
#
#
#
#
#
# Epoch 1/30
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6955 - accuracy: 0.4822 - val_loss: 0.6906 - val_accuracy: 0.5647
# Epoch 2/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6887 - accuracy: 0.5482 - val_loss: 0.6880 - val_accuracy: 0.4706
# Epoch 3/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6892 - accuracy: 0.5482 - val_loss: 0.6896 - val_accuracy: 0.4471
# Epoch 4/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.5482 - val_loss: 0.6933 - val_accuracy: 0.5765
# Epoch 5/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6842 - accuracy: 0.5584 - val_loss: 0.6913 - val_accuracy: 0.5412
# Epoch 6/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6829 - accuracy: 0.5787 - val_loss: 0.6911 - val_accuracy: 0.5647
# Epoch 7/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6814 - accuracy: 0.5736 - val_loss: 0.6909 - val_accuracy: 0.5765
# Epoch 8/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.5838 - val_loss: 0.6912 - val_accuracy: 0.5765
# Epoch 9/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6794 - accuracy: 0.5584 - val_loss: 0.6942 - val_accuracy: 0.5882
# Epoch 10/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6787 - accuracy: 0.5888 - val_loss: 0.6979 - val_accuracy: 0.5412
# Epoch 11/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.5685 - val_loss: 0.6953 - val_accuracy: 0.4706
# Epoch 12/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6758 - accuracy: 0.5888 - val_loss: 0.6941 - val_accuracy: 0.5529
# Epoch 13/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6756 - accuracy: 0.5533 - val_loss: 0.6999 - val_accuracy: 0.5529
# Epoch 14/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6748 - accuracy: 0.5787 - val_loss: 0.6984 - val_accuracy: 0.5647
# Epoch 15/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6680 - accuracy: 0.6193 - val_loss: 0.6975 - val_accuracy: 0.5176
# Epoch 16/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6679 - accuracy: 0.6142 - val_loss: 0.6969 - val_accuracy: 0.5059
# Epoch 17/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6684 - accuracy: 0.5990 - val_loss: 0.6972 - val_accuracy: 0.5059
# Epoch 18/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6621 - accuracy: 0.6294 - val_loss: 0.6944 - val_accuracy: 0.5176
# Epoch 19/30
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6608 - accuracy: 0.6142 - val_loss: 0.6990 - val_accuracy: 0.5412
# Epoch 20/30
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6560 - accuracy: 0.6396 - val_loss: 0.7036 - val_accuracy: 0.4941
# Epoch 21/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6562 - accuracy: 0.6244 - val_loss: 0.7062 - val_accuracy: 0.4824
# Epoch 22/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6465 - accuracy: 0.6447 - val_loss: 0.6987 - val_accuracy: 0.5294
# Epoch 23/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6442 - accuracy: 0.6091 - val_loss: 0.6984 - val_accuracy: 0.5529
# Epoch 24/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6454 - accuracy: 0.6497 - val_loss: 0.7061 - val_accuracy: 0.5529
# Epoch 25/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6376 - accuracy: 0.6447 - val_loss: 0.7111 - val_accuracy: 0.5059
# Epoch 26/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6650 - val_loss: 0.7177 - val_accuracy: 0.4588
# Epoch 27/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6358 - accuracy: 0.6497 - val_loss: 0.7205 - val_accuracy: 0.4588
# Epoch 28/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6340 - accuracy: 0.6345 - val_loss: 0.7343 - val_accuracy: 0.4235
# Epoch 29/30
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6273 - accuracy: 0.6345 - val_loss: 0.7363 - val_accuracy: 0.4941
# Epoch 30/30
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6204 - accuracy: 0.6650 - val_loss: 0.7322 - val_accuracy: 0.4824
#
#
#
#
#
# Epoch 1/30
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6902 - accuracy: 0.5526 - val_loss: 0.6998 - val_accuracy: 0.4388
# Epoch 2/30
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6842 - accuracy: 0.5526 - val_loss: 0.7078 - val_accuracy: 0.4082
# Epoch 3/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6786 - accuracy: 0.5526 - val_loss: 0.6873 - val_accuracy: 0.5612
# Epoch 4/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5877 - val_loss: 0.6840 - val_accuracy: 0.5816
# Epoch 5/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6756 - accuracy: 0.5921 - val_loss: 0.6881 - val_accuracy: 0.5510
# Epoch 6/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6734 - accuracy: 0.5833 - val_loss: 0.6927 - val_accuracy: 0.5510
# Epoch 7/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6700 - accuracy: 0.5921 - val_loss: 0.6968 - val_accuracy: 0.5714
# Epoch 8/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6672 - accuracy: 0.5877 - val_loss: 0.6960 - val_accuracy: 0.5918
# Epoch 9/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6638 - accuracy: 0.5965 - val_loss: 0.6846 - val_accuracy: 0.6224
# Epoch 10/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6639 - accuracy: 0.5965 - val_loss: 0.6752 - val_accuracy: 0.6020
# Epoch 11/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6581 - accuracy: 0.6053 - val_loss: 0.7045 - val_accuracy: 0.5408
# Epoch 12/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6578 - accuracy: 0.6272 - val_loss: 0.6995 - val_accuracy: 0.5408
# Epoch 13/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6542 - accuracy: 0.6053 - val_loss: 0.6779 - val_accuracy: 0.6122
# Epoch 14/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6499 - accuracy: 0.6184 - val_loss: 0.6993 - val_accuracy: 0.5714
# Epoch 15/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6534 - accuracy: 0.6184 - val_loss: 0.7232 - val_accuracy: 0.5408
# Epoch 16/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6535 - accuracy: 0.6228 - val_loss: 0.6983 - val_accuracy: 0.5816
# Epoch 17/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6450 - accuracy: 0.6316 - val_loss: 0.7034 - val_accuracy: 0.5408
# Epoch 18/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6441 - accuracy: 0.6535 - val_loss: 0.6867 - val_accuracy: 0.5714
# Epoch 19/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6426 - accuracy: 0.6491 - val_loss: 0.6651 - val_accuracy: 0.6020
# Epoch 20/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6488 - accuracy: 0.6096 - val_loss: 0.6589 - val_accuracy: 0.6429
# Epoch 21/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6386 - accuracy: 0.6272 - val_loss: 0.6949 - val_accuracy: 0.5816
# Epoch 22/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6411 - accuracy: 0.6491 - val_loss: 0.7062 - val_accuracy: 0.5204
# Epoch 23/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6798 - val_loss: 0.6888 - val_accuracy: 0.5510
# Epoch 24/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6288 - accuracy: 0.6754 - val_loss: 0.6935 - val_accuracy: 0.5816
# Epoch 25/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6294 - accuracy: 0.6886 - val_loss: 0.7111 - val_accuracy: 0.5612
# Epoch 26/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6287 - accuracy: 0.6842 - val_loss: 0.7002 - val_accuracy: 0.5918
# Epoch 27/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6225 - accuracy: 0.6667 - val_loss: 0.6764 - val_accuracy: 0.5408
# Epoch 28/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6162 - accuracy: 0.6798 - val_loss: 0.7134 - val_accuracy: 0.5204
# Epoch 29/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.6623 - val_loss: 0.6864 - val_accuracy: 0.5204
# Epoch 30/30
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6182 - accuracy: 0.6623 - val_loss: 0.7124 - val_accuracy: 0.5204
#
#
#
#
#
# Epoch 1/30
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6802 - accuracy: 0.5425 - val_loss: 0.6596 - val_accuracy: 0.5986
# Epoch 2/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6552 - accuracy: 0.6364 - val_loss: 0.6245 - val_accuracy: 0.6871
# Epoch 3/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6366 - accuracy: 0.6481 - val_loss: 0.5968 - val_accuracy: 0.6939
# Epoch 4/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6197 - accuracy: 0.6540 - val_loss: 0.5696 - val_accuracy: 0.7007
# Epoch 5/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6061 - accuracy: 0.6510 - val_loss: 0.5437 - val_accuracy: 0.7279
# Epoch 6/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5898 - accuracy: 0.6540 - val_loss: 0.5269 - val_accuracy: 0.7347
# Epoch 7/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5724 - accuracy: 0.6950 - val_loss: 0.5254 - val_accuracy: 0.7619
# Epoch 8/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.6921 - val_loss: 0.5014 - val_accuracy: 0.7619
# Epoch 9/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5378 - accuracy: 0.7155 - val_loss: 0.5297 - val_accuracy: 0.7551
# Epoch 10/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5573 - accuracy: 0.7302 - val_loss: 0.4985 - val_accuracy: 0.7619
# Epoch 11/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5259 - accuracy: 0.7478 - val_loss: 0.4629 - val_accuracy: 0.7959
# Epoch 12/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7625 - val_loss: 0.4743 - val_accuracy: 0.7619
# Epoch 13/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4982 - accuracy: 0.7830 - val_loss: 0.4433 - val_accuracy: 0.8299
# Epoch 14/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4638 - accuracy: 0.8123 - val_loss: 0.4447 - val_accuracy: 0.7891
# Epoch 15/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4562 - accuracy: 0.8211 - val_loss: 0.4236 - val_accuracy: 0.8095
# Epoch 16/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4421 - accuracy: 0.8328 - val_loss: 0.4074 - val_accuracy: 0.8231
# Epoch 17/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4243 - accuracy: 0.8358 - val_loss: 0.3994 - val_accuracy: 0.8435
# Epoch 18/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.8299 - val_loss: 0.3991 - val_accuracy: 0.8231
# Epoch 19/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4024 - accuracy: 0.8328 - val_loss: 0.4125 - val_accuracy: 0.8231
# Epoch 20/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3987 - accuracy: 0.8328 - val_loss: 0.3755 - val_accuracy: 0.8163
# Epoch 21/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3755 - accuracy: 0.8592 - val_loss: 0.3666 - val_accuracy: 0.8435
# Epoch 22/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8504 - val_loss: 0.3542 - val_accuracy: 0.8707
# Epoch 23/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3526 - accuracy: 0.8710 - val_loss: 0.3659 - val_accuracy: 0.8231
# Epoch 24/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.8651 - val_loss: 0.3561 - val_accuracy: 0.8571
# Epoch 25/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3399 - accuracy: 0.8768 - val_loss: 0.3393 - val_accuracy: 0.8435
# Epoch 26/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3298 - accuracy: 0.8768 - val_loss: 0.3326 - val_accuracy: 0.8503
# Epoch 27/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3215 - accuracy: 0.8680 - val_loss: 0.3315 - val_accuracy: 0.8503
# Epoch 28/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3200 - accuracy: 0.8739 - val_loss: 0.3336 - val_accuracy: 0.8571
# Epoch 29/30
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2997 - accuracy: 0.8886 - val_loss: 0.3197 - val_accuracy: 0.8571
# Epoch 30/30
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2938 - accuracy: 0.8856 - val_loss: 0.3187 - val_accuracy: 0.8639

# %%
X_train.shape
# Out:
# (298, 8)
