# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.feature_selection import VarianceThreshold, f_classif

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Outcomes

# %%
outcomes = pd.read_csv('Dados/Puro-txt/Outcomes.txt',sep='\t')
outcomes.set_index('Probes',inplace=True)
ae = pd.DataFrame(outcomes['AdverseEvent_Class'])
ae.columns = ['AE_Class']
ar = pd.DataFrame(outcomes['AntibodyResponse_Class'])
ar.columns = ['AR_Class']
ar = ar.dropna()
ae['AE_Class'] = ae['AE_Class'].apply(lambda x: 0 if x == 'NO' else 1)
ar['AR_Class'] = ar['AR_Class'].apply(lambda x: 0 if x == 'Waned' else 1)

# %% [markdown]
# # Extract, de-log and rescale

# %%
df = pd.read_csv('Dados/Puro-txt/1v0.txt',sep='\t')
df.set_index('Probes',inplace=True)
df = df.astype(float)
df = df.T
df = df.loc[probes]
df = 2**df
cols = df.columns
idxs=df.index
min_max_scaler = preprocessing.MinMaxScaler()
df = pd.DataFrame(min_max_scaler.fit_transform(df))
df.columns = cols
df.index = idxs
df
# Out:
# Probes     MARC1    MARCH1     MARC2    MARCH2    MARCH3    MARCH5    MARCH6  \
# Probes
# G305    0.242012  0.160667  0.334218  0.128834  0.423837  0.383878  0.549269
# G102    0.097947  0.969388  0.057645  0.292160  0.011729  0.280620  0.277724
# G120    0.175804  0.499479  0.462908  0.152632  0.256344  0.894201  0.533709
# G105    0.208543  0.182351  0.062311  0.179667  0.248777  0.105611  0.366059
# G304    0.105972  0.767500  0.037707  0.189626  0.406686  0.557530  0.220183
# G103    0.687914  0.626070  1.000000  0.039832  0.206149  0.448911  0.396101
# G302    0.252608  0.680510  0.397873  0.219217  0.224016  0.384148  0.186984
# G117    0.154402  0.598467  0.348424  0.191624  0.294116  0.481406  0.179836
# G314    0.068547  0.164524  0.237721  0.458674  0.365822  0.168426  0.748628
# G101    0.094070  0.596269  0.663537  0.081769  0.245174  0.522050  0.233343
# G337    0.049104  0.367822  0.092790  0.759612  0.615842  0.434874  0.322549
# ...

# %% [markdown]
# ## Export

# %%
df.to_csv('Dados/Tratado-csv/1v0.csv')
ae.to_csv('Dados/Tratado-csv/AdverseEvent.csv')
ar.to_csv('Dados/Tratado-csv/AntibodyResponse.csv')
