# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %% [markdown]
# ## Extract raw data and selected desired columns

# %%
dados = pd.read_csv('Dados/dados originais.tsv',sep=' ')
X = dados.iloc[:,3:-23]
colsx = x.columns
Y = dados.iloc[:,-8:]
Y.index = range(266)

# %% [markdown]
# ## De-log and normalize

# %%
X = 2**X
min_max_scaler = preprocessing.MinMaxScaler()
X = min_max_scaler.fit_transform(X)
X = pd.DataFrame(X)
X.columns = colsx
X
# Out:
#          AIRE      AREG     ASAP1      BCL2      BLR1      BMP6       BPI  \
# 0    0.000000  0.617393  0.000000  0.166472  0.063108  0.008148  0.048233
# 1    0.000000  0.722066  0.000000  0.088291  0.037261  0.005577  0.040766
# 2    0.000000  0.874382  0.047084  0.177581  0.068813  0.005297  0.060332
# 3    0.000000  0.753495  0.049825  0.130992  0.051503  0.006091  0.060332
# 4    0.008250  0.466882  0.042638  0.195444  0.039247  0.004775  0.034444
# ..        ...       ...       ...       ...       ...       ...       ...
# 261  0.000000  0.052577  0.006993  0.189324  0.047526  0.002940  0.008871
# 262  0.000000  0.002824  0.009618  0.177581  0.053414  0.004919  0.011862
# 263  0.014240  0.026044  0.029859  0.000000  0.063565  0.007745  0.015808
# 264  0.000000  0.004012  0.009399  0.177581  0.045816  0.004021  0.010189
# 265  0.003681  0.019034  0.012719  0.000000  0.043519  0.001749  0.011692
#
#        CAMTA1     CASP8      CCL2  ...     TLR10       TNF  TNFRSF1A  \
# 0    0.000000  0.480825  0.000000  ...  0.000000  0.008869  0.333492
# 1    0.000000  0.487687  0.000000  ...  0.000000  0.006003  0.492235
# 2    0.000000  0.586110  0.000000  ...  0.000000  0.010378  0.535672
# 3    0.000000  0.577893  0.000000  ...  0.000000  0.008225  0.531913
# 4    0.000000  0.477430  0.000000  ...  0.000000  0.007062  0.550972
# ..        ...       ...       ...  ...       ...       ...       ...
# 261  0.072400  0.167958  0.000000  ...  0.000000  0.009489  0.166058
# 262  0.000000  0.142688  0.001116  ...  0.071954  0.010691  0.139297
# 263  0.099507  0.120082  0.000000  ...  0.440432  0.012484  0.122861
# 264  0.000000  0.161872  0.000000  ...  0.069757  0.011598  0.138276
# 265  0.000000  0.144830  0.000000  ...  0.000000  0.011945  0.149909
#
#      TNFRSF1B  TNFRSF18     TNIP1  TWIST1      VEGF    ZNF331    ZNF532
# 0    0.667481  0.005392  0.010257     0.0  0.000000  0.136405  0.000000
# 1    0.681901  0.005895  0.070248     0.0  0.000000  0.000000  0.000000
# 2    0.972141  0.005895  0.064849     0.0  0.000000  0.000000  0.000000
# 3    0.979033  0.007254  0.052828     0.0  0.000000  0.040808  0.000000
# 4    0.630461  0.004278  0.054406     0.0  0.000000  0.011186  0.000000
# ..        ...       ...       ...     ...       ...       ...       ...
# 261  0.019325  0.032641  0.040132     0.0  0.024561  0.187361  0.014618
# 262  0.076385  0.000000  0.055618     0.0  0.043344  0.000000  0.000000
# 263  0.095182  0.067849  0.134896     0.0  0.093799  0.217360  0.026485
# 264  0.033280  0.000000  0.053611     0.0  0.029375  0.000000  0.000000
# 265  0.065220  0.007956  0.057696     0.0  0.036413  0.063669  0.011985
#
# [266 rows x 144 columns]

# %% [markdown]
# # Dataframe for classification of each event

# %% [markdown]
# ## Import dataframe and remove genes with low variance

# %%
tol = 0.005
for col in X.columns:
    if X[col].var() < 0.02:
        X.drop([col],axis=1,inplace=True)

print(f"Shape X: {X.shape}")
print(f"Shape Y: {Y.shape}")
# Out:
# Shape X: (266, 38)
# Shape Y: (266, 8)

# %% [markdown]
# ## Export

# %%
dados = pd.concat([X,Y],axis=1)
dados.to_csv('Dados/dados tratados.csv',index=False)
